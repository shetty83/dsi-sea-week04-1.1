# %%
import requests
import random
import numpy as np

word_site = "http://svnweb.freebsd.org/csrg/share/dict/words?view=co&content-type=text/plain"
response = requests.get(word_site)
WORDS = response.content.splitlines()
proper = [word for word in WORDS if word[0].isupper()]
not_proper = [word for word in WORDS if not word[0].isupper()]

class formWords:
    def __init__(self, proper, not_proper):
        self.proper = proper
        self.not_proper = not_proper
        
    def randomProper(self):
        return self.proper[np.random.randint(0,len(self.proper))]
    
    def randomNonProper(self):
        return self.not_proper[np.random.randint(0,len(self.not_proper))]
        
    def randomNumber(self,digits):
        return str(random.sample(range(10 ** (digits - 1), 10 ** (digits)), 1)[0])
    
    def randomPostfix(self):
        postfix = ['Street','Ave', 'Blvd', 'Lane', 'Court']
        return postfix[np.random.randint(1,len(postfix))]
    
    def randomEmailProvider(self):
        provider = ['gmail','yahoo', 'live', 'compuserve', 'aol']
        return provider[np.random.randint(1,len(provider))]
    
    def randomState(self):
        states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
        return states[np.random.randint(1,len(states))]
        
    def generateText(self, blog_length):
        form = self.getForm()
        blog = []
        for x in range(blog_length):
            choice = np.random.randint(1,50)
            if choice < 38:
                blog += [self.randomNonProper()]
            elif choice < 40:
                blog += [form['email']()]
            elif choice < 44:
                blog += [form['name']()]
            elif choice < 46:
                blog += [form['password']()]
            elif choice < 50:
                blog += [form['address']()]
    
        return " ".join(blog)

    def getForm(self):
        return {
            'email' : lambda : "Email: " + self.randomNumber(4) + self.randomNonProper().lower() + 
                "@" + self.randomEmailProvider() + ".com",
            'name' : lambda : "Name: " + self.randomProper() + " " + self.randomProper(),
            'password' : lambda : "Password: " + self.randomNumber(2) + self.randomNonProper() + 
                self.randomNumber(3) + self.randomProper().lower(),
            'address' : lambda : "Address: " + self.randomNumber(3) + " " + self.randomProper() + 
                " " + self.randomPostfix() + ", " + self.randomProper() + " " + self.randomState() + 
                ", " + self.randomNumber(5),
        }

words = formWords(proper, not_proper)

# %%
print words.getForm()['email']()
print words.getForm()['name']()
print words.getForm()['password']()
print words.getForm()['address']()

#This is the data variable
data = words.generateText(10000)
print data[:100]
# Out:
# Email: 2890thicken@live.com
# Name: Bessel Henri
# Password: 40watch338conestoga
# Address: 896 Torrance Blvd, Loveland AR, 45421
# Email: 3490derail@compuserve.com zenith archdiocese hydrofluoric fume Address: 765 Lomb Blvd, Schwab

# %% [markdown]
# ### Pull all the emails from the data variable

# %%
import re
re.findall('\s+(\w*@\w*.com)', data)
# Out:
# ['5317sawfish@aol.com',
#  '5516necromancy@yahoo.com',
#  '2400sapphire@live.com',
#  '1321abundant@live.com',
#  '3729short@compuserve.com',
#  '7297gigawatt@yahoo.com',
#  '5627unitarian@aol.com',
#  '4922ski@compuserve.com',
#  '4730valley@live.com',
#  '5546scrubby@yahoo.com',
#  '8427criss@aol.com',
#  '9334phosphorescent@compuserve.com',
#  '1745pentane@live.com',
#  '6007cozy@live.com',
#  '1780insect@aol.com',
#  '2775galena@compuserve.com',
#  '1329tern@live.com',
#  '9924pill@yahoo.com',
#  '5873car@live.com',
#  '1226slum@yahoo.com',
#  '7667sniffle@compuserve.com',
#  '3485process@compuserve.com',
#  '6219marque@yahoo.com',
#  '6269smallish@yahoo.com',
#  '8518starlight@live.com',
#  '3254bottom@aol.com']

# %% [markdown]
# ### Pull all the names from the data variable

# %%
name = re.findall(':\s+([A-Z]{1}[a-z]+\s[A-Z]{1}[a-z]+)', data)

# %% [markdown]
# ### Pull all the passwords from the data variable

# %%
pas = re.findall('\s+([0-9]{2}[a-z]+[0-9]+[a-z]+)',data)

len(pas)
# Out:
# 446

# %% [markdown]
# ### Pull all the addresses from the data variable

# %%
address = re.findall('\s+([0-9]{3}\s[A-Za-z]+\s[A-Za-z]+,\s[A-Za-z]+\s[A-Z]{2},\s[0-9]{5})', data)

# 896 Torrance Blvd, Loveland AR, 45421

# %% [markdown]
# ### Which state had the most addresses in your data?

# %%
states = re.findall('\s+[0-9]{3}\s[A-Za-z]+\s[A-Za-z]+,\s[A-Za-z]+\s([A-Z]{2}),\s[0-9]{5}', data)
import pandas as pd

pd.Series(states).value_counts()
# Out:
# DC    27
# WV    25
# MN    23
# MD    22
# TN    22
# CA    22
# NH    21
# ME    21
# NJ    21
# OR    21
# MI    20
# KS    20
# MS    20
# CT    20
# TX    20
# KY    20
# IN    20
# AR    20
# OK    20
# NM    19
# AK    19
# MO    18
# PA    18
# AZ    17
# VT    17
# NV    15
# SD    15
# ID    15
# SC    15
# OH    15
# LA    14
# WI    14
# WY    14
# UT    14
# NE    14
# MA    14
# DE    13
# CO    13
# NY    13
# ND    12
# MT    12
# WA    12
# VA    11
# NC    11
# IA    11
# FL    11
# HI    11
# RI    10
# IL    10
# GA     7
# dtype: int64

# %% [markdown]
# ### Do we have any famous people in our data?
# #### Check to see if there are any user names that are also city/street names

# %%
streets = re.findall('Address:\s[0-9]*\s+(\w*)\s', data)
famous = []
for n in name:
    for s in streets:
        if (s in n) & (n not in famous):
            famous.append(n)
        else:
            continue

famous

# %% [markdown]
# ### What is the value count of the zipcodes in your addresses?

# %%
zip = re.findall('\s([0-9]{5})', data)

pd.Series(zip).value_counts()
# Out:
# 54455    2
# 86209    2
# 15623    2
# 48818    2
# 31513    2
# 70472    1
# 65582    1
# 81110    1
# 34341    1
# 60128    1
# 89641    1
# 82800    1
# 31477    1
# 52881    1
# 65648    1
# 57844    1
# 97020    1
# 71177    1
# 77458    1
# 79120    1
# 83224    1
# 43195    1
# 11203    1
# 92882    1
# 98375    1
# 44351    1
# 75926    1
# 95020    1
# 28411    1
# 23607    1
#         ..
# 74458    1
# 80679    1
# 58577    1
# 67348    1
# 15468    1
# 72685    1
# 47243    1
# 70633    1
# 32450    1
# 41362    1
# 81996    1
# 95999    1
# 42322    1
# 87934    1
# 69199    1
# 11639    1
# 24810    1
# 47242    1
# 36310    1
# 61946    1
# 92114    1
# 11062    1
# 92444    1
# 50724    1
# 38242    1
# 92119    1
# 15465    1
# 59296    1
# 16405    1
# 44284    1
# dtype: int64
